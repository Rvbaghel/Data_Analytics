# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

df=pd.read_csv('emp.csv')

df
# Out:
#       ID Gender  Experience (Years)                      Position  Salary
# 0      1      F                   4               DevOps Engineer  109976
# 1      2      M                   6               DevOps Engineer  120088
# 2      3      M                  17                 Web Developer  181301
# 3      4      M                   7         Systems Administrator   77530
# 4      5      F                  13         Systems Administrator  152397
# ..   ...    ...                 ...                           ...     ...
# 395  396      F                  19     Cloud Solutions Architect  236045
# 396  397      F                  20                 Web Developer  182770
# 397  398      F                   9         Network Administrator   85550
# 398  399      M                  18  Database Administrator (DBA)  129996
# 399  400      F                  11           IT Security Analyst  169058
#
# [400 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# ID                    0
# Gender                0
# Experience (Years)    0
# Position              0
# Salary                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  400 non-null    int64
#  1   Gender              400 non-null    object
#  2   Experience (Years)  400 non-null    int64
#  3   Position            400 non-null    object
#  4   Salary              400 non-null    int64
# dtypes: int64(3), object(2)
# memory usage: 15.8+ KB

# %%
x=df.groupby('Position')['Salary'].mean()

x=x.sort_values()
plt.figure(figsize=(10,5))

plt.title('Average Salary of each Position')
plt.barh(x.index,x.values)
plt.xlabel("Salary Avarage")
plt.show()

# %%
fre=df['Gender'].value_counts() 
plt.title('Gender Distribution')
plt.pie(fre,labels=fre.index,autopct='%1.1f%%',startangle=90)
plt.axis('equal')
plt.show()

# %%
fre=df['Gender'].value_counts() 

plt.title('Gender Distribution')

plt.bar(fre.index,fre.values,color=['#bbbfff','#fffbbb'],width=0.5)
plt.xlabel('Genders')
plt.ylabel('Frequency')
plt.show()

# %%
expe = df[(df['Experience (Years)'] >= 10) & (df['Experience (Years)'] <= 15)]

range_salay = expe['Salary']

plt.hist(range_salay, bins=5, edgecolor='black')
plt.title('Salary Distribution for 10-15 Years Experience')
plt.xlabel('Salary ($)')
plt.ylabel('Frequency')
plt.show()

# %%
position_counts = df['Position'].value_counts()

plt.barh(position_counts.index, position_counts.values)

plt.title('Number of Employees by Position')
plt.xlabel('Position')
plt.ylabel('Number of Employees')
plt.grid(axis='y')
plt.show()

# %%
plt.barh(df['Position'],df['Salary'])

plt.title('Number of Employees by Position')
plt.xlabel('Salary')
plt.ylabel('Position')
plt.grid(True)
plt.show()
